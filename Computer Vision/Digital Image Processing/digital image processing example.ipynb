# %% [markdown]
# <span style="color: #800080; font-weight: bold;">✨ Digital Image Processing Basic Examples ✨</span>
#
# Here, Iam providing the basic examples of digital image processing for beginners, including loading the image, converting it into grayscale, performing edge detection, and more.

# %% [markdown]
# #### Import Necessary libraries
#
# Here we need to import 'cv2', which is used for image processing tasks, and 'matplotlib', which is used for visualization.

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# #### 🖼️ Load the image path and read the image

# %%
# Load the image
image_path = "C:/Users/gokul/OneDrive/Pictures/IMG_4221_edited.jpg"  #specify the image path
image = cv2.imread(image_path)

# %% [markdown]
# #### 🌈 Convert the image into grayscale with cv2.COLOR_BGR2GRAY ⚪⚫

# %%
# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# #### Blur the image 🌫️

# %%
# Apply Gaussian blur to the grayscale image
blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

# %% [markdown]
# #### Apply Edge detection with Canny 🔍

# %%
# Perform edge detection using Canny
edges = cv2.Canny(blurred_image, 50, 150)

# %% [markdown]
# #### Perform Thresholding on the blurred image

# %%
# Thresholding
_, thresholded_image = cv2.threshold(blurred_image, 100, 255, cv2.THRESH_BINARY)

# %% [markdown]
# #### Apply Contour detection
#
#  It is a technique used in image processing to find and outline the boundaries of objects in an image

# %%
# Contour detection
contours, _ = cv2.findContours(edges.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
# Draw contours on the original image
contour_image = image.copy()
cv2.drawContours(contour_image, contours, -1, (0, 255, 0), 2)
# Out:
# array([[[ 21,  22,   6],
#         [ 21,  22,   6],
#         [ 22,  23,   7],
#         ...,
#         [ 74,  93,  38],
#         [ 75,  94,  39],
#         [ 76,  95,  40]],
#
#        [[ 21,  22,   6],
#         [ 21,  22,   6],
#         [ 22,  23,   7],
#         ...,
#         [ 74,  93,  38],
#         [ 75,  94,  39],
#         [ 75,  94,  39]],
#
#        [[ 21,  22,   6],
#         [ 21,  22,   6],
#         [ 22,  23,   7],
#         ...,
#         [ 74,  93,  38],
#         [ 74,  93,  38],
#         [ 74,  93,  38]],
#
#        ...,
#
#        [[ 73, 226, 233],
#         [ 74, 227, 234],
#         [ 72, 225, 232],
#         ...,
#         [ 97,  82,  63],
#         [ 96,  81,  62],
#         [ 97,  82,  63]],
#
#        [[ 76, 227, 234],
#         [ 72, 225, 232],
#         [ 72, 225, 232],
#         ...,
#         [ 97,  82,  63],
#         [ 98,  83,  64],
#         [ 99,  84,  65]],
#
#        [[ 66, 226, 232],
#         [ 63, 223, 229],
#         [ 64, 226, 231],
# ...

# %% [markdown]
# #### Visualise all the actions performed

# %%
# Display the images
plt.figure(figsize=(16, 8))

# Original Image
plt.subplot(2, 3, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')

# Grayscale Image
plt.subplot(2, 3, 2)
plt.imshow(gray_image, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

# Blurred Image
plt.subplot(2, 3, 3)
plt.imshow(blurred_image, cmap='gray')
plt.title('Blurred')
plt.axis('off')


# Edge Detected Image
plt.subplot(2, 3, 4)
plt.imshow(edges, cmap='gray')
plt.title('Edge Detected Image')
plt.axis('off')

# Thresholded Image
plt.subplot(2, 3, 5)
plt.imshow(thresholded_image, cmap='gray')
plt.title('Thresholded')
plt.axis('off')

# Contour Detected Image
plt.subplot(2, 3, 6)
plt.imshow(cv2.cvtColor(contour_image, cv2.COLOR_BGR2RGB))
plt.title('Contours')
plt.axis('off')

plt.tight_layout()
plt.show()
